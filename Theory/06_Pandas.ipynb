# %% [markdown]
# # Pandas
#
# The `numpy` module is excellent for numerical computations, but to handle missing data or arrays with mixed types takes more work. The `pandas` module is currently the most widely used tool for data manipulation, providing high-performance, easy-to-use data structures and advanced data analysis tools.
#
# In particular `pandas` features:
#
# * A fast and efficient "DataFrame" object for data manipulation with integrated indexing;
# * Tools for reading and writing data between in-memory data structures and different formats (CSV, Excel, SQL, HDF5);
# * Intelligent data alignment and integrated handling of missing data;
# * Intelligent label-based slicing, fancy indexing, and subsetting of large data sets;
# * Aggregating or transforming data with a powerful "group-by" engine;
# * High performance merging and joining of data sets;
# * Hierarchical axis indexing provides an intuitive way of working with high-dimensional data in a lower-dimensional data structure;
# * Time series-functionalities;
# * Highly optimized for performance, with critical code paths written in Cython or C.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Series
#
# Series are completely equivalent to 1D array but with axis labels and the possibility to store heterogeneous elements. Of paramount importance are the time-series, used to define time evolutions of a phenomenon.

# %%
from string import ascii_lowercase as letters

# Creating a series, accessing indexes, values and values by their index 
xs = pd.Series(np.arange(10)*0.5, index=tuple(letters[:10]))
print ("xs:", xs,'\n')
print ("xs indexes:",xs.index,'\n')
# Values of the Series are actually a numpy array
print ("xs values:", xs.values, type(xs.values),'\n')
print (xs['f'], xs.f, xs.h, '\n')
print (xs[['d', 'f', 'h']], '\n')
print (type(xs[['d', 'f', 'h']]), '\n')
# Out:
# xs: a    0.0
# b    0.5
# c    1.0
# d    1.5
# e    2.0
# f    2.5
# g    3.0
# h    3.5
# i    4.0
# j    4.5
# dtype: float64
#
# xs indexes: Index(['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j'], dtype='object')
#
# xs values: [0.  0.5 1.  1.5 2.  2.5 3.  3.5 4.  4.5] <class 'numpy.ndarray'>
#
# 2.5 2.5 3.5
#
# d    1.5
# f    2.5
# h    3.5
# dtype: float64
#
# <class 'pandas.core.series.Series'>

# %%
# Extracting elements and operations: same as numpy array
print (xs[:3],'\n')
print (xs[7:], '\n')
print (xs[::3], '\n')
print (xs[xs>3], '\n')
print (np.exp(xs), '\n')
print (np.mean(xs), np.std(xs), '\n')
# Out:
# a    0.0
# b    0.5
# c    1.0
# dtype: float64
#
# h    3.5
# i    4.0
# j    4.5
# dtype: float64
#
# a    0.0
# d    1.5
# g    3.0
# j    4.5
# dtype: float64
#
# h    3.5
# i    4.0
# j    4.5
# dtype: float64
#
# a     1.000000
# b     1.648721
# c     2.718282
# d     4.481689
# e     7.389056
# f    12.182494
# g    20.085537
# h    33.115452
# i    54.598150
# j    90.017131
# dtype: float64
#
# 2.25 1.4361406616345072

# %%
# Series can be created from python dictionary too.
# Not that the elements can be whatever!
d = {'b' : 1, 'a' : 'cat', 'c' : [2,3]}
pd.Series(d)
# Out:
# b         1
# a       cat
# c    [2, 3]
# dtype: object

# %% [markdown]
# A key difference between Series and ndarray is that operations between Series automatically align the data based on label. Thus, you can write computations without considering whether the Series involved have the same labels.

# %%
s = pd.Series(np.random.randn(5), index=tuple(letters[:5]))
print(s)
s = s[1:] + s[:-1]
print(s)
# Out:
# a    1.239794
# b   -0.204419
# c    0.851407
# d   -1.634686
# e   -1.868138
# dtype: float64
# a         NaN
# b   -0.408839
# c    1.702813
# d   -3.269373
# e         NaN
# dtype: float64

# %% [markdown]
# ### Time series
#
# Time series are very often used to profile the behaviour of a quantity as a function of time. Pandas has a special index for that, `DatetimeIndex`, that can be created e.g. with the function `pd.data_range()`

# %%
# to define a date, the datetime module is very useful
import datetime as dt
date = dt.date.today()
print(date)

date = dt.datetime(2023,11,22,10,45,10,15)
print (date)

# otherwise, several notations are interpreted too
date = 'Nov 22 2023'
# or alternatively
date = '22/11/2023 10:45:00'
print (date)

days = pd.date_range(date, periods=7, freq='D')
print (days)

seconds = pd.date_range(date, periods=3600, freq='s')
print (seconds)
# Out:
# 2023-11-29
# 2023-11-22 10:45:10.000015
# 22/11/2023 10:45:00
# DatetimeIndex(['2023-11-22 10:45:00', '2023-11-23 10:45:00',
#                '2023-11-24 10:45:00', '2023-11-25 10:45:00',
#                '2023-11-26 10:45:00', '2023-11-27 10:45:00',
#                '2023-11-28 10:45:00'],
#               dtype='datetime64[ns]', freq='D')
# DatetimeIndex(['2023-11-22 10:45:00', '2023-11-22 10:45:01',
#                '2023-11-22 10:45:02', '2023-11-22 10:45:03',
#                '2023-11-22 10:45:04', '2023-11-22 10:45:05',
#                '2023-11-22 10:45:06', '2023-11-22 10:45:07',
#                '2023-11-22 10:45:08', '2023-11-22 10:45:09',
#                ...
#                '2023-11-22 11:44:50', '2023-11-22 11:44:51',
#                '2023-11-22 11:44:52', '2023-11-22 11:44:53',
#                '2023-11-22 11:44:54', '2023-11-22 11:44:55',
#                '2023-11-22 11:44:56', '2023-11-22 11:44:57',
#                '2023-11-22 11:44:58', '2023-11-22 11:44:59'],
#               dtype='datetime64[ns]', length=3600, freq='S')

# %% [markdown]
# To learn more about the frequency strings, please see this [link](http://pandas.pydata.org/pandas-docs/stable/timeseries.html#offset-aliases)
#
#
# Timestamped data is the most basic type of time series data that associates values with points in time. For pandas objects it means using the points in time.
#
# functions like `pd.to_datetime` can be used, for instance, when reading information as string from a dataset.
#
# Timestamp is the pandas equivalent of python’s Datetime and is interchangeable with it in most cases.

# %%
tstamp = pd.Timestamp(dt.datetime(2020, 11, 9))

# internally it counts the nanoseconds from January 1st 19
#tstamp = pd.Timestamp(dt.datetime(1970, 1, 1, 0, 0, 0, 1))
print(tstamp.value)

# when creating a timestamp the format can be explicitly passed
ts = pd.to_datetime('2010/11/12', format='%Y/%m/%d')
print (type(ts))
print (ts.value)
ts = pd.to_datetime('12-11-2010 00:00', format='%d-%m-%Y %H:%M')
print (ts)
print (ts.value)
# Out:
# 1604880000000000000
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# 1289520000000000000
# 2010-11-12 00:00:00
# 1289520000000000000

# %% [markdown]
# A standard series can be created and (range of) elements can be used as indexes

# %%
tseries = pd.Series(np.random.normal(10, 1, len(days)), index=days)
# Extracting elements
print (tseries[0:4], '\n')
print (tseries['2023-11-22':'2023-11-28'], '\n') # Note - includes end time
# Out:
# 2023-11-22 10:45:00    10.986408
# 2023-11-23 10:45:00    10.897902
# 2023-11-24 10:45:00    10.147905
# 2023-11-25 10:45:00    10.491394
# Freq: D, dtype: float64
#
# 2023-11-22 10:45:00    10.986408
# 2023-11-23 10:45:00    10.897902
# 2023-11-24 10:45:00    10.147905
# 2023-11-25 10:45:00    10.491394
# 2023-11-26 10:45:00    11.732038
# 2023-11-27 10:45:00    11.368910
# 2023-11-28 10:45:00     9.331329
# Freq: D, dtype: float64

# %% [markdown]
# `pd.to_datetime` can also be used to create a `DatetimeIndex`:

# %%
pd.to_datetime([1, 2, 3, 4], unit='D', origin=pd.Timestamp('1980-02-03'))
# Out:
# DatetimeIndex(['1980-02-04', '1980-02-05', '1980-02-06', '1980-02-07'], dtype='datetime64[ns]', freq=None)

# %% [markdown]
# ## DataFrame
#
# A pandas DataFrame is like a simple tabular spreadsheet. For future reference (or for people already familiar with R), a pandas DataFrame is very similar to the R DataFrame.
#
# Each column in a DataFrame is a Series object.
#
# The element can be whatever, missing data are dealt with too (as NaN)

# %% [markdown]
# ### DataFrame creation
#
# A DataFrame can be created implicitly, with, e.g., a DatatimeIndex object as index:

# %%
entries=10
dates=pd.date_range('11/22/2023 10:45:00',freq='h', periods=entries)
df = pd.DataFrame(np.random.randn(entries,4), index=dates, columns=['A','B','C','D'])
df
# Out:
#                             A         B         C         D
# 2023-11-22 10:45:00  0.611648  0.920438 -1.618401 -1.052819
# 2023-11-22 11:45:00 -0.000624 -1.470945  0.417921  0.504190
# 2023-11-22 12:45:00  1.810593  0.868095  0.620694  2.449748
# 2023-11-22 13:45:00 -1.175588 -0.515230  1.378798 -0.429528
# 2023-11-22 14:45:00 -0.214514  1.289201 -0.718235 -1.730353
# 2023-11-22 15:45:00  0.237217  0.978927 -0.357488  0.725955
# 2023-11-22 16:45:00  0.143103  1.028336  0.158912  0.544551
# 2023-11-22 17:45:00 -0.292198 -0.209244  0.696871  0.315897
# 2023-11-22 18:45:00 -0.189708 -0.623308 -1.141323 -1.533620
# 2023-11-22 19:45:00 -0.101698  1.908330  1.537450 -0.717919

# %% [markdown]
# or by means of a dictionary:

# %%
df2 = pd.DataFrame(
    { 'A' : 1.,
      'B' : pd.Timestamp('20130102'),
      'C' : pd.Series(1,index=range(4),dtype='float32'),
      'D' : np.arange(7,11),
      'E' : pd.Categorical(["test","train","test","train"]),
    }
    )
df2

# check what happens if D and E had different lenghts
# Out:
#      A          B    C   D      E
# 0  1.0 2013-01-02  1.0   7   test
# 1  1.0 2013-01-02  1.0   8  train
# 2  1.0 2013-01-02  1.0   9   test
# 3  1.0 2013-01-02  1.0  10  train

# %% [markdown]
# ### Viewing Data

# %%
df.head(2)
# Out:
#                             A         B         C         D
# 2023-11-22 10:45:00  0.611648  0.920438 -1.618401 -1.052819
# 2023-11-22 11:45:00 -0.000624 -1.470945  0.417921  0.504190

# %%
df.tail(4)
# Out:
#                             A         B         C         D
# 2023-11-22 16:45:00  0.143103  1.028336  0.158912  0.544551
# 2023-11-22 17:45:00 -0.292198 -0.209244  0.696871  0.315897
# 2023-11-22 18:45:00 -0.189708 -0.623308 -1.141323 -1.533620
# 2023-11-22 19:45:00 -0.101698  1.908330  1.537450 -0.717919

# %%
df.index
# Out:
# DatetimeIndex(['2023-11-22 10:45:00', '2023-11-22 11:45:00',
#                '2023-11-22 12:45:00', '2023-11-22 13:45:00',
#                '2023-11-22 14:45:00', '2023-11-22 15:45:00',
#                '2023-11-22 16:45:00', '2023-11-22 17:45:00',
#                '2023-11-22 18:45:00', '2023-11-22 19:45:00'],
#               dtype='datetime64[ns]', freq='H')

# %%
df.columns
# Out:
# Index(['A', 'B', 'C', 'D'], dtype='object')

# %%
df.values
# Out:
# array([[ 6.11647760e-01,  9.20437755e-01, -1.61840146e+00,
#         -1.05281890e+00],
#        [-6.23630272e-04, -1.47094473e+00,  4.17920830e-01,
#          5.04190285e-01],
#        [ 1.81059339e+00,  8.68095327e-01,  6.20694186e-01,
#          2.44974809e+00],
#        [-1.17558816e+00, -5.15230466e-01,  1.37879768e+00,
#         -4.29527833e-01],
#        [-2.14513566e-01,  1.28920141e+00, -7.18234671e-01,
#         -1.73035322e+00],
#        [ 2.37217146e-01,  9.78926564e-01, -3.57487655e-01,
#          7.25955140e-01],
#        [ 1.43103398e-01,  1.02833606e+00,  1.58912367e-01,
#          5.44551364e-01],
#        [-2.92198132e-01, -2.09244287e-01,  6.96871269e-01,
#          3.15896796e-01],
#        [-1.89708248e-01, -6.23308181e-01, -1.14132334e+00,
#         -1.53361997e+00],
#        [-1.01697525e-01,  1.90833045e+00,  1.53745014e+00,
#         -7.17919187e-01]])

# %%
df.describe()
# Out:
#                A          B          C          D
# count  10.000000  10.000000  10.000000  10.000000
# mean    0.082823   0.417460   0.097520  -0.092390
# std     0.761596   1.056148   1.043820   1.258213
# min    -1.175588  -1.470945  -1.618401  -1.730353
# 25%    -0.208312  -0.438734  -0.628048  -0.969094
# 50%    -0.051161   0.894267   0.288417  -0.056816
# 75%     0.213689   1.015984   0.677827   0.534461
# max     1.810593   1.908330   1.537450   2.449748

# %%
df.T
# Out:
#    2023-11-22 10:45:00  2023-11-22 11:45:00  2023-11-22 12:45:00  \
# A             0.611648            -0.000624             1.810593
# B             0.920438            -1.470945             0.868095
# C            -1.618401             0.417921             0.620694
# D            -1.052819             0.504190             2.449748
#
#    2023-11-22 13:45:00  2023-11-22 14:45:00  2023-11-22 15:45:00  \
# A            -1.175588            -0.214514             0.237217
# B            -0.515230             1.289201             0.978927
# C             1.378798            -0.718235            -0.357488
# D            -0.429528            -1.730353             0.725955
#
#    2023-11-22 16:45:00  2023-11-22 17:45:00  2023-11-22 18:45:00  \
# A             0.143103            -0.292198            -0.189708
# B             1.028336            -0.209244            -0.623308
# C             0.158912             0.696871            -1.141323
# D             0.544551             0.315897            -1.533620
#
#    2023-11-22 19:45:00
# A            -0.101698
# B             1.908330
# C             1.537450
# D            -0.717919

# %%
df.sort_index(axis=0,ascending=False)
# Out:
#                             A         B         C         D
# 2023-11-22 19:45:00 -0.101698  1.908330  1.537450 -0.717919
# 2023-11-22 18:45:00 -0.189708 -0.623308 -1.141323 -1.533620
# 2023-11-22 17:45:00 -0.292198 -0.209244  0.696871  0.315897
# 2023-11-22 16:45:00  0.143103  1.028336  0.158912  0.544551
# 2023-11-22 15:45:00  0.237217  0.978927 -0.357488  0.725955
# 2023-11-22 14:45:00 -0.214514  1.289201 -0.718235 -1.730353
# 2023-11-22 13:45:00 -1.175588 -0.515230  1.378798 -0.429528
# 2023-11-22 12:45:00  1.810593  0.868095  0.620694  2.449748
# 2023-11-22 11:45:00 -0.000624 -1.470945  0.417921  0.504190
# 2023-11-22 10:45:00  0.611648  0.920438 -1.618401 -1.052819

# %%
df.sort_values(by="C")
# Out:
#                             A         B         C         D
# 2023-11-22 10:45:00  0.611648  0.920438 -1.618401 -1.052819
# 2023-11-22 18:45:00 -0.189708 -0.623308 -1.141323 -1.533620
# 2023-11-22 14:45:00 -0.214514  1.289201 -0.718235 -1.730353
# 2023-11-22 15:45:00  0.237217  0.978927 -0.357488  0.725955
# 2023-11-22 16:45:00  0.143103  1.028336  0.158912  0.544551
# 2023-11-22 11:45:00 -0.000624 -1.470945  0.417921  0.504190
# 2023-11-22 12:45:00  1.810593  0.868095  0.620694  2.449748
# 2023-11-22 17:45:00 -0.292198 -0.209244  0.696871  0.315897
# 2023-11-22 13:45:00 -1.175588 -0.515230  1.378798 -0.429528
# 2023-11-22 19:45:00 -0.101698  1.908330  1.537450 -0.717919

# %% [markdown]
# ## Selection
#
# ### Getting slices
#
# The following show how to get part of the DataFrame (i.e. not just the elements)

# %%
## standard and safe
print (df['A'],'\n')

## equivalent but dangerous (imagine blank spaces in the name of the column..)
print (df.A)
# Out:
# 2023-11-22 10:45:00    0.611648
# 2023-11-22 11:45:00   -0.000624
# 2023-11-22 12:45:00    1.810593
# 2023-11-22 13:45:00   -1.175588
# 2023-11-22 14:45:00   -0.214514
# 2023-11-22 15:45:00    0.237217
# 2023-11-22 16:45:00    0.143103
# 2023-11-22 17:45:00   -0.292198
# 2023-11-22 18:45:00   -0.189708
# 2023-11-22 19:45:00   -0.101698
# Freq: H, Name: A, dtype: float64
#
# 2023-11-22 10:45:00    0.611648
# 2023-11-22 11:45:00   -0.000624
# 2023-11-22 12:45:00    1.810593
# 2023-11-22 13:45:00   -1.175588
# 2023-11-22 14:45:00   -0.214514
# 2023-11-22 15:45:00    0.237217
# 2023-11-22 16:45:00    0.143103
# 2023-11-22 17:45:00   -0.292198
# 2023-11-22 18:45:00   -0.189708
# 2023-11-22 19:45:00   -0.101698
# Freq: H, Name: A, dtype: float64

# %%
# selecting rows by counting
print (df[0:3])

# or by index
print (df["2023-11-22 10:45:00":"2023-11-22 12:45:00"])
# Out:
#                             A         B         C         D
# 2023-11-22 10:45:00  0.611648  0.920438 -1.618401 -1.052819
# 2023-11-22 11:45:00 -0.000624 -1.470945  0.417921  0.504190
# 2023-11-22 12:45:00  1.810593  0.868095  0.620694  2.449748
#                             A         B         C         D
# 2023-11-22 10:45:00  0.611648  0.920438 -1.618401 -1.052819
# 2023-11-22 11:45:00 -0.000624 -1.470945  0.417921  0.504190
# 2023-11-22 12:45:00  1.810593  0.868095  0.620694  2.449748

# %% [markdown]
# ### Selection by label

# %%
# getting a cross section (part of the DataFrame) using a label
df.loc[dates[0]]
# Out:
# A    0.611648
# B    0.920438
# C   -1.618401
# D   -1.052819
# Name: 2023-11-22 10:45:00, dtype: float64

# %%
# selecting on a multi-axis by label:
df.loc[:,['A','B']]
#a=df.loc[:,['A','B']]
# Out:
#                             A         B
# 2023-11-22 10:45:00  0.611648  0.920438
# 2023-11-22 11:45:00 -0.000624 -1.470945
# 2023-11-22 12:45:00  1.810593  0.868095
# 2023-11-22 13:45:00 -1.175588 -0.515230
# 2023-11-22 14:45:00 -0.214514  1.289201
# 2023-11-22 15:45:00  0.237217  0.978927
# 2023-11-22 16:45:00  0.143103  1.028336
# 2023-11-22 17:45:00 -0.292198 -0.209244
# 2023-11-22 18:45:00 -0.189708 -0.623308
# 2023-11-22 19:45:00 -0.101698  1.908330

# %%
# showing label slicing, both endpoints are included:
df.loc['2023-11-22 14:45:00':'2023-11-22 16:45:00',['A','B']]
# Out:
#                             A         B
# 2023-11-22 14:45:00 -0.214514  1.289201
# 2023-11-22 15:45:00  0.237217  0.978927
# 2023-11-22 16:45:00  0.143103  1.028336

# %%
# getting an individual element
print (df.loc[dates[1],'A'])

# equivalently
print (df.at[dates[1],'A'])
# Out:
# -0.0006236302724260604
# -0.0006236302724260604

# %% [markdown]
# ### Selecting by position

# %%
# select via the position of the passed integers:
print (df.iloc[3],'\n')

# notation similar to numpy/python
print (df.iloc[3:5,0:2])
# Out:
# A   -1.175588
# B   -0.515230
# C    1.378798
# D   -0.429528
# Name: 2023-11-22 13:45:00, dtype: float64
#
#                             A         B
# 2023-11-22 13:45:00 -1.175588 -0.515230
# 2023-11-22 14:45:00 -0.214514  1.289201

# %%
# selecting raws 1,2 and 4 for columns 0 and 2
df.iloc[[1,2,4],[0,2]]
# Out:
#                             A         C
# 2023-11-22 11:45:00 -0.000624  0.417921
# 2023-11-22 12:45:00  1.810593  0.620694
# 2023-11-22 14:45:00 -0.214514 -0.718235

# %%
# slicing rows explicitly
print (df.iloc[1:3,:],'\n')

# slicing columns explicitly
print (df.iloc[:,1:3])
# Out:
#                             A         B         C         D
# 2023-11-22 11:45:00 -0.000624 -1.470945  0.417921  0.504190
# 2023-11-22 12:45:00  1.810593  0.868095  0.620694  2.449748
#
#                             B         C
# 2023-11-22 10:45:00  0.920438 -1.618401
# 2023-11-22 11:45:00 -1.470945  0.417921
# 2023-11-22 12:45:00  0.868095  0.620694
# 2023-11-22 13:45:00 -0.515230  1.378798
# 2023-11-22 14:45:00  1.289201 -0.718235
# 2023-11-22 15:45:00  0.978927 -0.357488
# 2023-11-22 16:45:00  1.028336  0.158912
# 2023-11-22 17:45:00 -0.209244  0.696871
# 2023-11-22 18:45:00 -0.623308 -1.141323
# 2023-11-22 19:45:00  1.908330  1.537450

# %%
# selecting an individual element by position
df.iloc[1,1]
#df.iat[1,1]
# Out:
# -1.4709447308433325

# %% [markdown]
# ### Boolean index
#
# Very powerful way of filtering out data with certain features. Notation is very similar to numpy arrays.

# %%
# Filter by a boolean condition on the values of a single column
df[df['B'] > 0]
# Out:
#                             A         B         C         D
# 2023-11-22 10:45:00  0.611648  0.920438 -1.618401 -1.052819
# 2023-11-22 12:45:00  1.810593  0.868095  0.620694  2.449748
# 2023-11-22 14:45:00 -0.214514  1.289201 -0.718235 -1.730353
# 2023-11-22 15:45:00  0.237217  0.978927 -0.357488  0.725955
# 2023-11-22 16:45:00  0.143103  1.028336  0.158912  0.544551
# 2023-11-22 19:45:00 -0.101698  1.908330  1.537450 -0.717919

# %%
# Selecting on the basis of boolean conditions applied to the whole DataFrame
df[df>0]

# a DataFrame with the same shape is returned, with NaN's where condition is not met
# Out:
#                             A         B         C         D
# 2023-11-22 10:45:00  0.611648  0.920438       NaN       NaN
# 2023-11-22 11:45:00       NaN       NaN  0.417921  0.504190
# 2023-11-22 12:45:00  1.810593  0.868095  0.620694  2.449748
# 2023-11-22 13:45:00       NaN       NaN  1.378798       NaN
# 2023-11-22 14:45:00       NaN  1.289201       NaN       NaN
# 2023-11-22 15:45:00  0.237217  0.978927       NaN  0.725955
# 2023-11-22 16:45:00  0.143103  1.028336  0.158912  0.544551
# 2023-11-22 17:45:00       NaN       NaN  0.696871  0.315897
# 2023-11-22 18:45:00       NaN       NaN       NaN       NaN
# 2023-11-22 19:45:00       NaN  1.908330  1.537450       NaN

# %% [markdown]
# ### Setting
#
# Combination of selection and setting of values

# %%
# setting values by label (same as by position)
df.at[dates[0],'A'] = 0

# setting and assigning a numpy array
df.loc[:,'D'] = np.array([5] * len(df))

# defining a brend new column
df['E'] = np.arange(len(df))*0.5

# defining a brend new column by means of a pd.Series: indexes must be the same!
df['E prime'] = pd.Series(np.arange(len(df))*2, index=df.index)

# %%
df
# Out:
#                             A         B         C    D    E  E prime
# 2023-11-22 10:45:00  0.000000  0.920438 -1.618401  5.0  0.0        0
# 2023-11-22 11:45:00 -0.000624 -1.470945  0.417921  5.0  0.5        2
# 2023-11-22 12:45:00  1.810593  0.868095  0.620694  5.0  1.0        4
# 2023-11-22 13:45:00 -1.175588 -0.515230  1.378798  5.0  1.5        6
# 2023-11-22 14:45:00 -0.214514  1.289201 -0.718235  5.0  2.0        8
# 2023-11-22 15:45:00  0.237217  0.978927 -0.357488  5.0  2.5       10
# 2023-11-22 16:45:00  0.143103  1.028336  0.158912  5.0  3.0       12
# 2023-11-22 17:45:00 -0.292198 -0.209244  0.696871  5.0  3.5       14
# 2023-11-22 18:45:00 -0.189708 -0.623308 -1.141323  5.0  4.0       16
# 2023-11-22 19:45:00 -0.101698  1.908330  1.537450  5.0  4.5       18

# %%
def dcos(theta):
    theta = theta*(np.pi/180)
    return np.cos(theta)
 
df['cosine'] = pd.Series(df["E"].apply(dcos), index=df.index)
df
# Out:
#                             A         B         C    D    E  E prime    cosine
# 2023-11-22 10:45:00  0.000000  0.920438 -1.618401  5.0  0.0        0  1.000000
# 2023-11-22 11:45:00 -0.000624 -1.470945  0.417921  5.0  0.5        2  0.999962
# 2023-11-22 12:45:00  1.810593  0.868095  0.620694  5.0  1.0        4  0.999848
# 2023-11-22 13:45:00 -1.175588 -0.515230  1.378798  5.0  1.5        6  0.999657
# 2023-11-22 14:45:00 -0.214514  1.289201 -0.718235  5.0  2.0        8  0.999391
# 2023-11-22 15:45:00  0.237217  0.978927 -0.357488  5.0  2.5       10  0.999048
# 2023-11-22 16:45:00  0.143103  1.028336  0.158912  5.0  3.0       12  0.998630
# 2023-11-22 17:45:00 -0.292198 -0.209244  0.696871  5.0  3.5       14  0.998135
# 2023-11-22 18:45:00 -0.189708 -0.623308 -1.141323  5.0  4.0       16  0.997564
# 2023-11-22 19:45:00 -0.101698  1.908330  1.537450  5.0  4.5       18  0.996917

# %%
# another example of global setting
df2=df.copy()

df2[df2>0] = -df2
df2
# Out:
#                             A         B         C    D    E  E prime    cosine
# 2023-11-22 10:45:00  0.000000 -0.920438 -1.618401 -5.0  0.0        0 -1.000000
# 2023-11-22 11:45:00 -0.000624 -1.470945 -0.417921 -5.0 -0.5       -2 -0.999962
# 2023-11-22 12:45:00 -1.810593 -0.868095 -0.620694 -5.0 -1.0       -4 -0.999848
# 2023-11-22 13:45:00 -1.175588 -0.515230 -1.378798 -5.0 -1.5       -6 -0.999657
# 2023-11-22 14:45:00 -0.214514 -1.289201 -0.718235 -5.0 -2.0       -8 -0.999391
# 2023-11-22 15:45:00 -0.237217 -0.978927 -0.357488 -5.0 -2.5      -10 -0.999048
# 2023-11-22 16:45:00 -0.143103 -1.028336 -0.158912 -5.0 -3.0      -12 -0.998630
# 2023-11-22 17:45:00 -0.292198 -0.209244 -0.696871 -5.0 -3.5      -14 -0.998135
# 2023-11-22 18:45:00 -0.189708 -0.623308 -1.141323 -5.0 -4.0      -16 -0.997564
# 2023-11-22 19:45:00 -0.101698 -1.908330 -1.537450 -5.0 -4.5      -18 -0.996917

# %%
df
# Out:
#                             A         B         C    D    E  E prime    cosine
# 2023-11-22 10:45:00  0.000000  0.920438 -1.618401  5.0  0.0        0  1.000000
# 2023-11-22 11:45:00 -0.000624 -1.470945  0.417921  5.0  0.5        2  0.999962
# 2023-11-22 12:45:00  1.810593  0.868095  0.620694  5.0  1.0        4  0.999848
# 2023-11-22 13:45:00 -1.175588 -0.515230  1.378798  5.0  1.5        6  0.999657
# 2023-11-22 14:45:00 -0.214514  1.289201 -0.718235  5.0  2.0        8  0.999391
# 2023-11-22 15:45:00  0.237217  0.978927 -0.357488  5.0  2.5       10  0.999048
# 2023-11-22 16:45:00  0.143103  1.028336  0.158912  5.0  3.0       12  0.998630
# 2023-11-22 17:45:00 -0.292198 -0.209244  0.696871  5.0  3.5       14  0.998135
# 2023-11-22 18:45:00 -0.189708 -0.623308 -1.141323  5.0  4.0       16  0.997564
# 2023-11-22 19:45:00 -0.101698  1.908330  1.537450  5.0  4.5       18  0.996917

# %% [markdown]
# ### Dropping
#
# N.B.: dropping doesn't act permanently on the DataFrame, i.e. to get that do :
# ```python
# df = df.drop(....)
# ```

# %%
# Dropping by column
df.drop(['E prime'], axis=1)

#which is equivalent to
new_df=df.drop(columns=['E prime'])
new_df
# Out:
#                             A         B         C    D    E    cosine
# 2023-11-22 10:45:00  0.000000  0.920438 -1.618401  5.0  0.0  1.000000
# 2023-11-22 11:45:00 -0.000624 -1.470945  0.417921  5.0  0.5  0.999962
# 2023-11-22 12:45:00  1.810593  0.868095  0.620694  5.0  1.0  0.999848
# 2023-11-22 13:45:00 -1.175588 -0.515230  1.378798  5.0  1.5  0.999657
# 2023-11-22 14:45:00 -0.214514  1.289201 -0.718235  5.0  2.0  0.999391
# 2023-11-22 15:45:00  0.237217  0.978927 -0.357488  5.0  2.5  0.999048
# 2023-11-22 16:45:00  0.143103  1.028336  0.158912  5.0  3.0  0.998630
# 2023-11-22 17:45:00 -0.292198 -0.209244  0.696871  5.0  3.5  0.998135
# 2023-11-22 18:45:00 -0.189708 -0.623308 -1.141323  5.0  4.0  0.997564
# 2023-11-22 19:45:00 -0.101698  1.908330  1.537450  5.0  4.5  0.996917

# %%
# Dropping by raws
# safe and always working
df.drop(df.index[[1,2,3,4]])
# Out:
#                             A         B         C    D    E  E prime    cosine
# 2023-11-22 10:45:00  0.000000  0.920438 -1.618401  5.0  0.0        0  1.000000
# 2023-11-22 15:45:00  0.237217  0.978927 -0.357488  5.0  2.5       10  0.999048
# 2023-11-22 16:45:00  0.143103  1.028336  0.158912  5.0  3.0       12  0.998630
# 2023-11-22 17:45:00 -0.292198 -0.209244  0.696871  5.0  3.5       14  0.998135
# 2023-11-22 18:45:00 -0.189708 -0.623308 -1.141323  5.0  4.0       16  0.997564
# 2023-11-22 19:45:00 -0.101698  1.908330  1.537450  5.0  4.5       18  0.996917

# %%
df
# Out:
#                             A         B         C    D    E  E prime    cosine
# 2023-11-22 10:45:00  0.000000  0.920438 -1.618401  5.0  0.0        0  1.000000
# 2023-11-22 11:45:00 -0.000624 -1.470945  0.417921  5.0  0.5        2  0.999962
# 2023-11-22 12:45:00  1.810593  0.868095  0.620694  5.0  1.0        4  0.999848
# 2023-11-22 13:45:00 -1.175588 -0.515230  1.378798  5.0  1.5        6  0.999657
# 2023-11-22 14:45:00 -0.214514  1.289201 -0.718235  5.0  2.0        8  0.999391
# 2023-11-22 15:45:00  0.237217  0.978927 -0.357488  5.0  2.5       10  0.999048
# 2023-11-22 16:45:00  0.143103  1.028336  0.158912  5.0  3.0       12  0.998630
# 2023-11-22 17:45:00 -0.292198 -0.209244  0.696871  5.0  3.5       14  0.998135
# 2023-11-22 18:45:00 -0.189708 -0.623308 -1.141323  5.0  4.0       16  0.997564
# 2023-11-22 19:45:00 -0.101698  1.908330  1.537450  5.0  4.5       18  0.996917

# %%
# something like df.drop('index_name') 
# would work but the type of index must be specificed, 
# in particular with DatetimeIndex
df.drop(pd.to_datetime("2023-11-22 18:45:00"))
# Out:
#                             A         B         C    D    E  E prime    cosine
# 2023-11-22 10:45:00  0.000000  0.920438 -1.618401  5.0  0.0        0  1.000000
# 2023-11-22 11:45:00 -0.000624 -1.470945  0.417921  5.0  0.5        2  0.999962
# 2023-11-22 12:45:00  1.810593  0.868095  0.620694  5.0  1.0        4  0.999848
# 2023-11-22 13:45:00 -1.175588 -0.515230  1.378798  5.0  1.5        6  0.999657
# 2023-11-22 14:45:00 -0.214514  1.289201 -0.718235  5.0  2.0        8  0.999391
# 2023-11-22 15:45:00  0.237217  0.978927 -0.357488  5.0  2.5       10  0.999048
# 2023-11-22 16:45:00  0.143103  1.028336  0.158912  5.0  3.0       12  0.998630
# 2023-11-22 17:45:00 -0.292198 -0.209244  0.696871  5.0  3.5       14  0.998135
# 2023-11-22 19:45:00 -0.101698  1.908330  1.537450  5.0  4.5       18  0.996917

# %% [markdown]
# ## Missing data
#
# pandas primarily uses the value np.nan to represent missing data. It is by default not included in computations.

# %%
df_wNan = df[df>0]
df_wNan
# Out:
#                             A         B         C    D    E  E prime    cosine
# 2023-11-22 10:45:00       NaN  0.920438       NaN  5.0  NaN      NaN  1.000000
# 2023-11-22 11:45:00       NaN       NaN  0.417921  5.0  0.5      2.0  0.999962
# 2023-11-22 12:45:00  1.810593  0.868095  0.620694  5.0  1.0      4.0  0.999848
# 2023-11-22 13:45:00       NaN       NaN  1.378798  5.0  1.5      6.0  0.999657
# 2023-11-22 14:45:00       NaN  1.289201       NaN  5.0  2.0      8.0  0.999391
# 2023-11-22 15:45:00  0.237217  0.978927       NaN  5.0  2.5     10.0  0.999048
# 2023-11-22 16:45:00  0.143103  1.028336  0.158912  5.0  3.0     12.0  0.998630
# 2023-11-22 17:45:00       NaN       NaN  0.696871  5.0  3.5     14.0  0.998135
# 2023-11-22 18:45:00       NaN       NaN       NaN  5.0  4.0     16.0  0.997564
# 2023-11-22 19:45:00       NaN  1.908330  1.537450  5.0  4.5     18.0  0.996917

# %%
# dropping raws with at least a Nan
df_wNan.dropna(how='any')
# Out:
#                             A         B         C    D    E  E prime    cosine
# 2023-11-22 12:45:00  1.810593  0.868095  0.620694  5.0  1.0      4.0  0.999848
# 2023-11-22 16:45:00  0.143103  1.028336  0.158912  5.0  3.0     12.0  0.998630

# %%
# getting a mask
df_wNan.isna()
#df_wNan.notna()
# Out:
#                          A      B      C      D      E  E prime  cosine
# 2023-11-22 10:45:00   True  False   True  False   True     True   False
# 2023-11-22 11:45:00   True   True  False  False  False    False   False
# 2023-11-22 12:45:00  False  False  False  False  False    False   False
# 2023-11-22 13:45:00   True   True  False  False  False    False   False
# 2023-11-22 14:45:00   True  False   True  False  False    False   False
# 2023-11-22 15:45:00  False  False   True  False  False    False   False
# 2023-11-22 16:45:00  False  False  False  False  False    False   False
# 2023-11-22 17:45:00   True   True  False  False  False    False   False
# 2023-11-22 18:45:00   True   True   True  False  False    False   False
# 2023-11-22 19:45:00   True  False  False  False  False    False   False

# %%
# filling missing data
df_wNan.fillna(value=0)
# Out:
#                             A         B         C    D    E  E prime    cosine
# 2023-11-22 10:45:00  0.000000  0.920438  0.000000  5.0  0.0      0.0  1.000000
# 2023-11-22 11:45:00  0.000000  0.000000  0.417921  5.0  0.5      2.0  0.999962
# 2023-11-22 12:45:00  1.810593  0.868095  0.620694  5.0  1.0      4.0  0.999848
# 2023-11-22 13:45:00  0.000000  0.000000  1.378798  5.0  1.5      6.0  0.999657
# 2023-11-22 14:45:00  0.000000  1.289201  0.000000  5.0  2.0      8.0  0.999391
# 2023-11-22 15:45:00  0.237217  0.978927  0.000000  5.0  2.5     10.0  0.999048
# 2023-11-22 16:45:00  0.143103  1.028336  0.158912  5.0  3.0     12.0  0.998630
# 2023-11-22 17:45:00  0.000000  0.000000  0.696871  5.0  3.5     14.0  0.998135
# 2023-11-22 18:45:00  0.000000  0.000000  0.000000  5.0  4.0     16.0  0.997564
# 2023-11-22 19:45:00  0.000000  1.908330  1.537450  5.0  4.5     18.0  0.996917

# %% [markdown]
# Fill gaps forward or backward by propagating non-NA values forward or backward:

# %%
df_wNan.fillna(method='pad')
# Out:
#                             A         B         C    D    E  E prime    cosine
# 2023-11-22 10:45:00       NaN  0.920438       NaN  5.0  NaN      NaN  1.000000
# 2023-11-22 11:45:00       NaN  0.920438  0.417921  5.0  0.5      2.0  0.999962
# 2023-11-22 12:45:00  1.810593  0.868095  0.620694  5.0  1.0      4.0  0.999848
# 2023-11-22 13:45:00  1.810593  0.868095  1.378798  5.0  1.5      6.0  0.999657
# 2023-11-22 14:45:00  1.810593  1.289201  1.378798  5.0  2.0      8.0  0.999391
# 2023-11-22 15:45:00  0.237217  0.978927  1.378798  5.0  2.5     10.0  0.999048
# 2023-11-22 16:45:00  0.143103  1.028336  0.158912  5.0  3.0     12.0  0.998630
# 2023-11-22 17:45:00  0.143103  1.028336  0.696871  5.0  3.5     14.0  0.998135
# 2023-11-22 18:45:00  0.143103  1.028336  0.696871  5.0  4.0     16.0  0.997564
# 2023-11-22 19:45:00  0.143103  1.908330  1.537450  5.0  4.5     18.0  0.996917

# %% [markdown]
# ## Operations
#
# Here comes the most relevant advantage of DataFrame. Operations on columns are extremly fast, almost as fast as the actual operation between elements in a raw

# %%
# Some statistics (mean() just as an example)
# raws
print (df.mean(axis=0),'\n')
# columns
print (df.mean(axis=1),'\n')
# Out:
# A          0.021658
# B          0.417460
# C          0.097520
# D          5.000000
# E          2.250000
# E prime    9.000000
# cosine     0.998915
# dtype: float64
#
# 2023-11-22 10:45:00    0.757434
# 2023-11-22 11:45:00    1.063759
# 2023-11-22 12:45:00    2.042747
# 2023-11-22 13:45:00    1.883948
# 2023-11-22 14:45:00    2.336549
# 2023-11-22 15:45:00    2.765386
# 2023-11-22 16:45:00    3.189854
# 2023-11-22 17:45:00    3.384795
# 2023-11-22 18:45:00    3.434746
# 2023-11-22 19:45:00    4.548714
# Freq: H, dtype: float64

# %%
# global operations on columns
df.apply(np.cumsum)
# Out:
#                             A         B         C     D     E  E prime  \
# 2023-11-22 10:45:00  0.000000  0.920438 -1.618401   5.0   0.0        0
# 2023-11-22 11:45:00 -0.000624 -0.550507 -1.200481  10.0   0.5        2
# 2023-11-22 12:45:00  1.809970  0.317588 -0.579786  15.0   1.5        6
# 2023-11-22 13:45:00  0.634382 -0.197642  0.799011  20.0   3.0       12
# 2023-11-22 14:45:00  0.419868  1.091559  0.080777  25.0   5.0       20
# 2023-11-22 15:45:00  0.657085  2.070486 -0.276711  30.0   7.5       30
# 2023-11-22 16:45:00  0.800189  3.098822 -0.117799  35.0  10.5       42
# 2023-11-22 17:45:00  0.507990  2.889578  0.579073  40.0  14.0       56
# 2023-11-22 18:45:00  0.318282  2.266269 -0.562251  45.0  18.0       72
# 2023-11-22 19:45:00  0.216585  4.174600  0.975199  50.0  22.5       90
#
#                        cosine
# 2023-11-22 10:45:00  1.000000
# 2023-11-22 11:45:00  1.999962
# 2023-11-22 12:45:00  2.999810
# 2023-11-22 13:45:00  3.999467
# 2023-11-22 14:45:00  4.998858
# 2023-11-22 15:45:00  5.997906
# 2023-11-22 16:45:00  6.996536
# 2023-11-22 17:45:00  7.994670
# 2023-11-22 18:45:00  8.992234
# 2023-11-22 19:45:00  9.989152

# %%
df
# Out:
#                             A         B         C    D    E  E prime    cosine
# 2023-11-22 10:45:00  0.000000  0.920438 -1.618401  5.0  0.0        0  1.000000
# 2023-11-22 11:45:00 -0.000624 -1.470945  0.417921  5.0  0.5        2  0.999962
# 2023-11-22 12:45:00  1.810593  0.868095  0.620694  5.0  1.0        4  0.999848
# 2023-11-22 13:45:00 -1.175588 -0.515230  1.378798  5.0  1.5        6  0.999657
# 2023-11-22 14:45:00 -0.214514  1.289201 -0.718235  5.0  2.0        8  0.999391
# 2023-11-22 15:45:00  0.237217  0.978927 -0.357488  5.0  2.5       10  0.999048
# 2023-11-22 16:45:00  0.143103  1.028336  0.158912  5.0  3.0       12  0.998630
# 2023-11-22 17:45:00 -0.292198 -0.209244  0.696871  5.0  3.5       14  0.998135
# 2023-11-22 18:45:00 -0.189708 -0.623308 -1.141323  5.0  4.0       16  0.997564
# 2023-11-22 19:45:00 -0.101698  1.908330  1.537450  5.0  4.5       18  0.996917

# %%
df.apply(lambda x: x.max() - x.min())
# Out:
# A           2.986182
# B           3.379275
# C           3.155852
# D           0.000000
# E           4.500000
# E prime    18.000000
# cosine      0.003083
# dtype: float64

# %%
# syntax is as usual similar to that of numpy arrays
df['A']+df['B']
# Out:
# 2023-11-22 10:45:00    0.920438
# 2023-11-22 11:45:00   -1.471568
# 2023-11-22 12:45:00    2.678689
# 2023-11-22 13:45:00   -1.690819
# 2023-11-22 14:45:00    1.074688
# 2023-11-22 15:45:00    1.216144
# 2023-11-22 16:45:00    1.171439
# 2023-11-22 17:45:00   -0.501442
# 2023-11-22 18:45:00   -0.813016
# 2023-11-22 19:45:00    1.806633
# Freq: H, dtype: float64

# %% [markdown]
# Let's play it hard and load (in memory) a (relatively) large dataset

# %%
# WARNING! link in past notebook was wrong!, (if needed) get the right file from:
#!wget https://www.dropbox.com/s/xvjzaxzz3ysphme/data_000637.txt -P ~/data/

file_name="data_000637.txt"
data=pd.read_csv(file_name)
data.tail(10)
# Out:
#          HEAD  FPGA  TDC_CHANNEL   ORBIT_CNT  BX_COUNTER  TDC_MEAS
# 1310710     1     1           36  3869211171         427        13
# 1310711     1     1           39  3869211171         430         0
# 1310712     1     1           35  3869211171         429         4
# 1310713     1     0           64  3869211171         758        18
# 1310714     1     0           60  3869211171         762         2
# 1310715     1     0           62  3869211171         762        14
# 1310716     1     1            4  3869211171         763        11
# 1310717     1     0           64  3869211171         764         0
# 1310718     1     0          139  3869211171         769         0
# 1310719     1     0           61  3869211171         762        18

# %% [markdown]
# Let's now do some operations among (elements of) columns

# %%
# the one-liner killing it all
data['timens']=data['TDC_MEAS']*25/30+data['BX_COUNTER']*25

# %%
data['timens']
# Out:
# 0          59371.666667
# 1          59372.500000
# 2          63848.333333
# 3          63965.833333
# 4          69020.833333
#                ...
# 1310715    19061.666667
# 1310716    19084.166667
# 1310717    19100.000000
# 1310718    19225.000000
# 1310719    19065.000000
# Name: timens, Length: 1310720, dtype: float64

# %%
# the old slooow way
def conversion(data):
    result=[]
    for i in range(len(data)): 
        result.append(data.loc[data.index[i],'TDC_MEAS']*25/30.+data.loc[data.index[i],'BX_COUNTER']*25)
    return result

data['timens']=conversion(data)

# %% [markdown]
# ## Merge
#
# pandas provides various facilities for easily combining together Series, DataFrame, and Panel objects with various kinds of set logic for the indexes and relational algebra functionality in the case of join / merge-type operations.
#
# ### Concat
#
# concatenation (adding rows) is straightforward

# %%
rdf = pd.DataFrame(np.random.randn(10, 4))
rdf
# Out:
#           0         1         2         3
# 0 -0.727654  0.186689  0.591992  0.357883
# 1 -0.149213  0.138929 -0.523762  1.768474
# 2  0.993329 -0.668378 -0.234354 -0.570680
# 3 -0.716437  0.172246 -0.868783 -2.628385
# 4  0.387772  0.296410 -0.052170  1.885567
# 5 -0.058902 -0.751055  1.294669 -0.671178
# 6  1.137877 -0.341265  0.339766  1.977407
# 7 -0.131164 -0.758369 -0.399467 -0.478261
# 8 -0.023911 -0.516114  0.018848  0.513334
# 9 -0.636305  0.356811  1.690333  1.166729

# %%
# divide it into pieaces raw-wise
pieces = [rdf[:3], rdf[3:7], rdf[7:]]
pieces
# Out:
# [          0         1         2         3
#  0 -0.727654  0.186689  0.591992  0.357883
#  1 -0.149213  0.138929 -0.523762  1.768474
#  2  0.993329 -0.668378 -0.234354 -0.570680,
#            0         1         2         3
#  3 -0.716437  0.172246 -0.868783 -2.628385
#  4  0.387772  0.296410 -0.052170  1.885567
#  5 -0.058902 -0.751055  1.294669 -0.671178
#  6  1.137877 -0.341265  0.339766  1.977407,
#            0         1         2         3
#  7 -0.131164 -0.758369 -0.399467 -0.478261
#  8 -0.023911 -0.516114  0.018848  0.513334
#  9 -0.636305  0.356811  1.690333  1.166729]

# %%
# put it back together
#pd.concat(pieces)

# indexes can be ignored
pd.concat(pieces, ignore_index=True)

# in case of dimension mismatch, Nan are added where needed
# Out:
#           0         1         2         3
# 0 -0.727654  0.186689  0.591992  0.357883
# 1 -0.149213  0.138929 -0.523762  1.768474
# 2  0.993329 -0.668378 -0.234354 -0.570680
# 3 -0.716437  0.172246 -0.868783 -2.628385
# 4  0.387772  0.296410 -0.052170  1.885567
# 5 -0.058902 -0.751055  1.294669 -0.671178
# 6  1.137877 -0.341265  0.339766  1.977407
# 7 -0.131164 -0.758369 -0.399467 -0.478261
# 8 -0.023911 -0.516114  0.018848  0.513334
# 9 -0.636305  0.356811  1.690333  1.166729

# %%
# appending a single row (as a Series)
s = rdf.iloc[3]
rdf = pd.concat([rdf,s.to_frame().T], ignore_index=True)
rdf
# Out:
#            0         1         2         3
# 0  -0.727654  0.186689  0.591992  0.357883
# 1  -0.149213  0.138929 -0.523762  1.768474
# 2   0.993329 -0.668378 -0.234354 -0.570680
# 3  -0.716437  0.172246 -0.868783 -2.628385
# 4   0.387772  0.296410 -0.052170  1.885567
# 5  -0.058902 -0.751055  1.294669 -0.671178
# 6   1.137877 -0.341265  0.339766  1.977407
# 7  -0.131164 -0.758369 -0.399467 -0.478261
# 8  -0.023911 -0.516114  0.018848  0.513334
# 9  -0.636305  0.356811  1.690333  1.166729
# 10 -0.716437  0.172246 -0.868783 -2.628385

# %% [markdown]
# ### Merge/Join
#
# SQL like operations on table can be performed on DataFrames. This is all rather sophisticated, refer to the [doc](https://pandas.pydata.org/pandas-docs/stable/merging.html#merging) for more info/examples

# %%
left = pd.DataFrame({'key': ['foo', 'bar'], 'lval': [1, 2]})
print(left)
right = pd.DataFrame({'key': ['foo', 'bar'], 'rval': [4, 5]})
print(right)
pd.merge(left,right,on="key")
# Out:
#    key  lval
# 0  foo     1
# 1  bar     2
#    key  rval
# 0  foo     4
# 1  bar     5
#    key  lval  rval
# 0  foo     1     4
# 1  bar     2     5

# %% [markdown]
# ## Grouping
#
# By “group by” we are referring to a process involving one or more of the following steps:
#
# * Splitting the data into groups based on some criteria
# * Applying a function to each group independently
# * Combining the results into a data structure
#
#
# Grouping is one of the most powerful and at the same time most sofisticated action you can perform with DataFrames. Mastering it is key for an effective usage of Pandas and vectorized data analysis. Reading the [documentation](https://pandas.pydata.org/pandas-docs/stable/user_guide/groupby.html) or going through a [tutorial](https://realpython.com/pandas-groupby/) is warmly recommended.

# %%
gdf = pd.DataFrame({'A' : ['foo', 'bar', 'foo', 'bar',
                          'foo', 'bar', 'foo', 'foo'],
                    'B' : ['one', 'one', 'two', 'three',
                           'two', 'two', 'one', 'three'],
                    'C' : np.random.randn(8),
                    'D' : np.random.randn(8)})
gdf
# Out:
#      A      B         C         D
# 0  foo    one  1.822160 -0.466877
# 1  bar    one  0.642209  1.103157
# 2  foo    two -0.168933  1.062921
# 3  bar  three  0.299799 -1.271681
# 4  foo    two  1.008361  1.797171
# 5  bar    two  0.335701  2.180899
# 6  foo    one  0.997864 -0.397570
# 7  foo  three  1.767336 -2.123060

# %%
# Grouping and then applying the sum() 
# function to the resulting groups (effective only where number are there).
gdf.groupby('A').sum()
# Out:
#                      B         C         D
# A
# bar        onethreetwo  1.277708  2.012376
# foo  onetwotwoonethree  5.426788 -0.127414

# %% [markdown]
# ## Multi-indexing
#
#
# Hierarchical / Multi-level indexing allows sophisticated data analysis on higher dimensional data. In essence, it enables you to store and manipulate data with an arbitrary number of dimensions in lower dimensional data structures like Series (1d) and DataFrame (2d).

# %%
tuples = list(zip(['bar', 'bar', 'baz', 'baz', 'foo', 'foo', 'qux', 'qux'],
          ['one', 'two', 'one', 'two', 'one', 'two', 'one', 'two']))
multi_index = pd.MultiIndex.from_tuples(tuples, names=['first', 'second'])
print (multi_index,'\n')

s = pd.Series(np.random.randn(8), index=multi_index)
print (s)
# Out:
# MultiIndex([('bar', 'one'),
#             ('bar', 'two'),
#             ('baz', 'one'),
#             ('baz', 'two'),
#             ('foo', 'one'),
#             ('foo', 'two'),
#             ('qux', 'one'),
#             ('qux', 'two')],
#            names=['first', 'second'])
#
# first  second
# bar    one       0.076932
#        two      -0.414357
# baz    one       0.137652
#        two      -0.021330
# foo    one      -1.047225
#        two       2.079349
# qux    one      -0.364185
#        two       1.890538
# dtype: float64

# %%
# it enables further features of the groupby method,
# e.g. when group-by by multiple columns
gdf.groupby(['A','B']).sum()
# Out:
#                   C         D
# A   B
# bar one    0.642209  1.103157
#     three  0.299799 -1.271681
#     two    0.335701  2.180899
# foo one    2.820024 -0.864446
#     three  1.767336 -2.123060
#     two    0.839428  2.860092

# %%
# stack() method “compresses” a level in the DataFrame’s columns
gdf.groupby(['A','B']).sum().stack()
# Out:
# A    B
# bar  one    C    0.642209
#             D    1.103157
#      three  C    0.299799
#             D   -1.271681
#      two    C    0.335701
#             D    2.180899
# foo  one    C    2.820024
#             D   -0.864446
#      three  C    1.767336
#             D   -2.123060
#      two    C    0.839428
#             D    2.860092
# dtype: float64

# %% [markdown]
# ## Plotting
#
# Just a preview, more on the next lab class!

# %%
ts = pd.Series(np.random.randn(1000), index=pd.date_range('1/1/2000', periods=1000))
ts.cumsum().plot()
# Out:
# <Axes: >

# %%
import matplotlib.pyplot as plt

pdf=pd.DataFrame(np.random.randn(1000, 4), index=ts.index,columns=['A', 'B', 'C', 'D'])
pdf = pdf.cumsum()
plt.figure(); pdf.plot(); plt.legend(loc='best')
